# %% [markdown]
# # Nuclear_warheads 1945-2022 per country

# %% [markdown]
# This Data contains the availability of nucear warheads of countries between 1945-2022

# %%
# !pip install opendatasets bar_chart_race -q

# %%
import pandas as pd
import opendatasets as od
import bar_chart_race as bcr

# %%
DATASET_URL = 'https://www.kaggle.com/vaibhavchopra2/nuclear-warheads-countrywise-19452022'
downloaddata(DATASET_URL)
data = pd.read_csv('nuclear-warheads-countrywise-19452022/Nuclear_warheads 1945-2022 per country.csv')
data
# Out:
# Skipping, found downloaded files in "./nuclear-warheads-countrywise-19452022" (use force=True to force download)
#     Year United States Russia  United Kingdom  France  China  Israel  India  \
# 0   1945             2      0               0       0      0       0      0
# 1   1946             9      0               0       0      0       0      0
# 2   1947            13      0               0       0      0       0      0
# 3   1948            50      0               0       0      0       0      0
# 4   1949           170      1               0       0      0       0      0
# ..   ...           ...    ...             ...     ...    ...     ...    ...
# 73  2018         4,000  4,350             215     300    280      80    135
# 74  2019         3,800  4,490             215     300    290      85    140
# 75  2020         3,800  4,310             195     290    320      90    150
# 76  2021         5,550  6,225             225     290    350      90    156
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            78 non-null     int64
#  1   United States   78 non-null     object
#  2   Russia          78 non-null     object
#  3   United Kingdom  78 non-null     int64
#  4   France          78 non-null     int64
#  5   China           78 non-null     int64
#  6   Israel          78 non-null     int64
#  7   India           78 non-null     int64
#  8   Pakistan        78 non-null     int64
#  9   North Korea     78 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 6.2+ KB

# %% [markdown]
# Converting US and Russia Column data to integer type

# %%
data = data.replace(',','', regex=True)
data[['United States', 'Russia']] = data[['United States', 'Russia']].apply(pd.to_numeric)
data =data.set_index('Year')

# %% [markdown]
# ## Plotting a running BAR graph with Plotly

# %%
bcr.bar_chart_race(df=data, filename=None,title='Nuclear Warheads 1945-2022 per country',cmap='dark12_r')
# Out:
# <video width="964" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
